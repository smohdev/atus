# %%
import pandas as pd
import numpy as np
import pdfplumber

from IPython import display

# %% [markdown]
# # American Time Use Survey (ATUS) Data Dictionary
#
# Parse column name and description from the tables in the PDF documentation.

# %%
pdf = pdfplumber.open("data/Documentation/atusintcodebk0320.pdf")

# %%
page_tables = []
for page in pdf.pages[11:54]:    # pp. 12-54
    tables = page.extract_tables()
    page_tables.append(tables)

# %%
# check first, second, and third level length
# corresponds to #tables, #rows, #columns
for t in page_tables:
    print(f"{len(t):3d} {len(t[0]):3d} {len(t[0][0]):3d}")
# Out:
#   1  28   6
#   1   9   6
#   1  34   6
#   1  27   6
#   1  31   6
#   1  27   6
#   1  21   6
#   1  31   6
#   1  30   6
#   1  31   6
#   1  31   6
#   1  23   6
#   1  27   6
#   1  28   6
#   1  17   6
#   1  31   6
#   1  31   6
#   1  25   6
#   1  23   6
#   1  16   6
#   1  21   6
#   1  21   6
#   1  26   6
#   1  28   6
#   1  26   6
#   1  26   6
#   1  27   6
#   1  30   6
#   1  33   6
#   1  32   6
#   1  29   6
#   1  25   6
#   1  24   6
#   1  27   6
#   1  32   6
#   1  23   6
#   1  25   6
#   1  33   6
#   1  34   6
#   1  30   6
#   1  14   6
#   1  30   6
#   1   4   6

# %%
parsed = []
for t in page_tables:
    t0 = t[0]

    start_of_coldesc = [row[0] == 'Name' for row in t0]
    idx = np.concatenate((np.where(start_of_coldesc)[0], [len(t0)]))
    chunks = [t0[i1:i2] for i1, i2 in zip(idx[:-1],idx[1:])]
    
    for one_col_desc in chunks:
        assert one_col_desc[0] == ['Name', 'Description', None, None, None, 'File']
        clean_desc = {
            'name': one_col_desc[1][0],
            'description': one_col_desc[1][1].replace('\n', ' '),
            'file': one_col_desc[1][5].replace('\n', ' ').split(', '),
        }
        if len(one_col_desc) > 2:
            if one_col_desc[2][1].startswith("Edited"):
                clean_desc['edited universe'] = one_col_desc[2][2]
        assert (one_col_desc[1][2:5] == [None, None, '']) or (one_col_desc[1][2:5] == [None, None, None])
        parsed.append(clean_desc)

# %%
parsed = pd.DataFrame(parsed)

# %%
col = parsed['file']
a = []
for x in list(col.values):
    a.extend(x)

pd.Series(a).value_counts()
# Out:
# Respondent File          132
# Activity File             28
# Activity Summary File     19
# EC Roster File             7
# Who File                   4
# Roster File                4
# ATUS-CPS File              1
# All Files                  1
# EH Activity File           1
# dtype: int64

# %% [markdown]
# ## Activity File

# %%
columns = pd.read_csv("data/atusact-0320/atusact_0320.dat", nrows=1).columns

in_activityfile = parsed['file'].apply(lambda x: 'Activity File' in x or 'All Files' in x)

with pd.option_context("display.max_colwidth", 200):
    selected = parsed.loc[in_activityfile, ['name','description']]
    assert set(d) == set(selected['name'].values)
    display.display(selected.set_index('name').loc[d]
                    .style.set_properties(**{'text-align': 'left'}))
# Out:
# <style  type="text/css" >
# #T_b92cc_row0_col0,#T_b92cc_row1_col0,#T_b92cc_row2_col0,#T_b92cc_row3_col0,#T_b92cc_row4_col0,#T_b92cc_row5_col0,#T_b92cc_row6_col0,#T_b92cc_row7_col0,#T_b92cc_row8_col0,#T_b92cc_row9_col0,#T_b92cc_row10_col0,#T_b92cc_row11_col0,#T_b92cc_row12_col0,#T_b92cc_row13_col0,#T_b92cc_row14_col0,#T_b92cc_row15_col0,#T_b92cc_row16_col0,#T_b92cc_row17_col0,#T_b92cc_row18_col0,#T_b92cc_row19_col0,#T_b92cc_row20_col0,#T_b92cc_row21_col0,#T_b92cc_row22_col0,#T_b92cc_row23_col0,#T_b92cc_row24_col0,#T_b92cc_row25_col0,#T_b92cc_row26_col0,#T_b92cc_row27_col0,#T_b92cc_row28_col0{
#             text-align:  left;
#         }</style><table id="T_b92cc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b92cc_level0_row0" class="row_heading level0 row0" >TUCASEID</th>
#                         <td id="T_b92cc_row0_col0" class="data row0 col0" >ATUS Case ID (14-digit identifier)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row1" class="row_heading level0 row1" >TUACTIVITY_N</th>
#                         <td id="T_b92cc_row1_col0" class="data row1 col0" >Activity line number</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row2" class="row_heading level0 row2" >TUACTDUR24</th>
#                         <td id="T_b92cc_row2_col0" class="data row2 col0" >Duration of activity in minutes (last activity truncated at 4:00 a.m.)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row3" class="row_heading level0 row3" >TUCC5</th>
#                         <td id="T_b92cc_row3_col0" class="data row3 col0" >Was at least one of your own household children < 13 in your care  during this activity?</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row4" class="row_heading level0 row4" >TUCC5B</th>
#                         <td id="T_b92cc_row4_col0" class="data row4 col0" >Was at least one of your non-own household children < 13 in your  care during this activity?</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row5" class="row_heading level0 row5" >TRTCCTOT_LN</th>
#                         <td id="T_b92cc_row5_col0" class="data row5 col0" >Total time spent during activity providing secondary childcare for all  children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row6" class="row_heading level0 row6" >TRTCC_LN</th>
#                         <td id="T_b92cc_row6_col0" class="data row6 col0" >Total time spent during activity providing secondary child care for  household and own nonhousehold children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row7" class="row_heading level0 row7" >TRTCOC_LN</th>
#                         <td id="T_b92cc_row7_col0" class="data row7 col0" >Total time spent during activity providing secondary child care for  nonown, nonhousehold children <13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row8" class="row_heading level0 row8" >TUSTARTTIM</th>
#                         <td id="T_b92cc_row8_col0" class="data row8 col0" >Activity start time</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row9" class="row_heading level0 row9" >TUSTOPTIME</th>
#                         <td id="T_b92cc_row9_col0" class="data row9 col0" >Activity stop time</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row10" class="row_heading level0 row10" >TRCODEP</th>
#                         <td id="T_b92cc_row10_col0" class="data row10 col0" >Pooled six-digit activity code</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row11" class="row_heading level0 row11" >TRTIER1P</th>
#                         <td id="T_b92cc_row11_col0" class="data row11 col0" >Pooled lexicon tier 1: 1st and 2nd digits of 6-digit activity code</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row12" class="row_heading level0 row12" >TRTIER2P</th>
#                         <td id="T_b92cc_row12_col0" class="data row12 col0" >Pooled lexicon tiers 1 and 2: 1st four digits of 6-digit activity code</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row13" class="row_heading level0 row13" >TUCC8</th>
#                         <td id="T_b92cc_row13_col0" class="data row13 col0" >Other than household or own non-household children < 13, was  there a child 0-12 in your care during this activity?</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row14" class="row_heading level0 row14" >TUCUMDUR</th>
#                         <td id="T_b92cc_row14_col0" class="data row14 col0" >Cumulative duration of activity lengths in minutes; last activity not  truncated at 4:00am or 1440 minutes (cumulative total of  TUACTDUR for each TUCASEID)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row15" class="row_heading level0 row15" >TUCUMDUR24</th>
#                         <td id="T_b92cc_row15_col0" class="data row15 col0" >Cumulative duration of activity lengths in minutes; last activity  truncated at 4:00am or 1440 minutes (cumulative total of  TUACTDUR24 for each TUCASEID)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row16" class="row_heading level0 row16" >TUACTDUR</th>
#                         <td id="T_b92cc_row16_col0" class="data row16 col0" >Duration of activity in minutes (last activity not truncated at 4:00  a.m.)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row17" class="row_heading level0 row17" >TR_03CC57</th>
#                         <td id="T_b92cc_row17_col0" class="data row17 col0" >Was a household or own non-household child < 13 in your care  during this activity?</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row18" class="row_heading level0 row18" >TRTO_LN</th>
#                         <td id="T_b92cc_row18_col0" class="data row18 col0" >Total time spent during activity providing secondary childcare for  own children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row19" class="row_heading level0 row19" >TRTONHH_LN</th>
#                         <td id="T_b92cc_row19_col0" class="data row19 col0" >Total time spent during activity providing secondary childcare for  own nonhousehold children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row20" class="row_heading level0 row20" >TRTOHH_LN</th>
#                         <td id="T_b92cc_row20_col0" class="data row20 col0" >Total time spent during activity providing secondary childcare for  own household children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row21" class="row_heading level0 row21" >TRTHH_LN</th>
#                         <td id="T_b92cc_row21_col0" class="data row21 col0" >Total time spent during activity providing secondary childcare for  household children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row22" class="row_heading level0 row22" >TRTNOHH_LN</th>
#                         <td id="T_b92cc_row22_col0" class="data row22 col0" >Total time spent during activity providing secondary childcare for  nonown household children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_b92cc_level0_row23" class="row_heading level0 row23" >TEWHERE</th>
#                         <td id="T_b92cc_row23_col0" class="data row23 col0" >E

# %% [markdown]
# ## Activity summary file
#
# - contains 431 `t<6 digit code>` columns.

# %%
columns = pd.read_csv("data/atussum-0320/atussum_0320.dat", nrows=1).columns

print("number of t?????? columns =", len(columns[columns.str.startswith('t')].str[1:]))
columns = columns[~columns.str.startswith('t')]
in_activitysumfile = parsed['file'].apply(lambda x: 'Activity Summary File' in x or 'All Files' in x)

with pd.option_context("display.max_colwidth", 200):
    selected = parsed.loc[in_activitysumfile, ['name','description']]
    try:
        assert set(columns) == set(selected['name'].values)
    except AssertionError:
        print("columns not in the Data Book", end=': ')
        print(set(columns) - set(selected['name'].values))
    display.display(selected.set_index('name').loc[[x for x in columns if x in selected['name'].values]]
                    .style.set_properties(**{'text-align': 'left'}))
# Out:
# number of t?????? columns = 431
# columns not in the Data Book: {'PEEDUCA', 'GEMETSTA', 'PEHSPNON', 'GTMETSTA', 'PTDTRACE'}
# <style  type="text/css" >
# #T_1a66e_row0_col0,#T_1a66e_row1_col0,#T_1a66e_row2_col0,#T_1a66e_row3_col0,#T_1a66e_row4_col0,#T_1a66e_row5_col0,#T_1a66e_row6_col0,#T_1a66e_row7_col0,#T_1a66e_row8_col0,#T_1a66e_row9_col0,#T_1a66e_row10_col0,#T_1a66e_row11_col0,#T_1a66e_row12_col0,#T_1a66e_row13_col0,#T_1a66e_row14_col0,#T_1a66e_row15_col0,#T_1a66e_row16_col0,#T_1a66e_row17_col0,#T_1a66e_row18_col0,#T_1a66e_row19_col0{
#             text-align:  left;
#         }</style><table id="T_1a66e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >description</th>    </tr>    <tr>        <th class="index_name level0" >name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a66e_level0_row0" class="row_heading level0 row0" >TUCASEID</th>
#                         <td id="T_1a66e_row0_col0" class="data row0 col0" >ATUS Case ID (14-digit identifier)</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row1" class="row_heading level0 row1" >TEAGE</th>
#                         <td id="T_1a66e_row1_col0" class="data row1 col0" >Edited: age</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row2" class="row_heading level0 row2" >TELFS</th>
#                         <td id="T_1a66e_row2_col0" class="data row2 col0" >Edited: labor force status</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row3" class="row_heading level0 row3" >TEMJOT</th>
#                         <td id="T_1a66e_row3_col0" class="data row3 col0" >Edited: in the last seven days did you have more than one job?</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row4" class="row_heading level0 row4" >TESCHENR</th>
#                         <td id="T_1a66e_row4_col0" class="data row4 col0" >Edited: are you enrolled in high school, college, or university?</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row5" class="row_heading level0 row5" >TESCHLVL</th>
#                         <td id="T_1a66e_row5_col0" class="data row5 col0" >Edited: would that be high school, college, or university?</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row6" class="row_heading level0 row6" >TESEX</th>
#                         <td id="T_1a66e_row6_col0" class="data row6 col0" >Edited: sex</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row7" class="row_heading level0 row7" >TESPEMPNOT</th>
#                         <td id="T_1a66e_row7_col0" class="data row7 col0" >Edited: employment status of spouse or unmarried partner</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row8" class="row_heading level0 row8" >TRCHILDNUM</th>
#                         <td id="T_1a66e_row8_col0" class="data row8 col0" >Number of household children < 18</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row9" class="row_heading level0 row9" >TRDPFTPT</th>
#                         <td id="T_1a66e_row9_col0" class="data row9 col0" >Full time or part time employment status of respondent</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row10" class="row_heading level0 row10" >TRERNWA</th>
#                         <td id="T_1a66e_row10_col0" class="data row10 col0" >Weekly earnings at main job (2 implied decimals)</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row11" class="row_heading level0 row11" >TRHOLIDAY</th>
#                         <td id="T_1a66e_row11_col0" class="data row11 col0" >Flag to indicate if diary day was a holiday</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row12" class="row_heading level0 row12" >TRSPFTPT</th>
#                         <td id="T_1a66e_row12_col0" class="data row12 col0" >Full time or part time employment status of spouse or unmarried  partner</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row13" class="row_heading level0 row13" >TRSPPRES</th>
#                         <td id="T_1a66e_row13_col0" class="data row13 col0" >Presence of the respondent's spouse or unmarried partner in the  household</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row14" class="row_heading level0 row14" >TRYHHCHILD</th>
#                         <td id="T_1a66e_row14_col0" class="data row14 col0" >Age of youngest household child < 18</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row15" class="row_heading level0 row15" >TUDIARYDAY</th>
#                         <td id="T_1a66e_row15_col0" class="data row15 col0" >Day of the week of diary day (day of the week about which the  respondent was interviewed)</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row16" class="row_heading level0 row16" >TUFNWGTP</th>
#                         <td id="T_1a66e_row16_col0" class="data row16 col0" >ATUS final weight</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row17" class="row_heading level0 row17" >TEHRUSLT</th>
#                         <td id="T_1a66e_row17_col0" class="data row17 col0" >Edited: total hours usually worked per week (sum of TEHRUSL1 and  TEHRUSL2)</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row18" class="row_heading level0 row18" >TUYEAR</th>
#                         <td id="T_1a66e_row18_col0" class="data row18 col0" >Year of diary day (year of day about which respondent was  interviewed)</td>
#             </tr>
#             <tr>
#                         <th id="T_1a66e_level0_row19" class="row_heading level0 row19" >TU20FWGT</th>
#                         <td id="T_1a66e_row19_col0" class="data row19 col0" >ATUS final weight for 2020 data</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Respondent File

# %%
columns = pd.read_csv('data/atusresp-0320/atusresp_0320.dat', nrows=1).columns

in_respfile = parsed['file'].apply(lambda x: 'Respondent File' in x or 'All Files' in x)

with pd.option_context("display.max_colwidth", 200):
    selected = parsed.loc[in_respfile, ['name','description']]
    assert set(columns) == set(selected['name'].values)
    display.display(selected.set_index('name').loc[columns]
                    .style.set_properties(**{'text-align': 'left'}))
# Out:
# <style  type="text/css" >
# #T_ae78b_row0_col0,#T_ae78b_row1_col0,#T_ae78b_row2_col0,#T_ae78b_row3_col0,#T_ae78b_row4_col0,#T_ae78b_row5_col0,#T_ae78b_row6_col0,#T_ae78b_row7_col0,#T_ae78b_row8_col0,#T_ae78b_row9_col0,#T_ae78b_row10_col0,#T_ae78b_row11_col0,#T_ae78b_row12_col0,#T_ae78b_row13_col0,#T_ae78b_row14_col0,#T_ae78b_row15_col0,#T_ae78b_row16_col0,#T_ae78b_row17_col0,#T_ae78b_row18_col0,#T_ae78b_row19_col0,#T_ae78b_row20_col0,#T_ae78b_row21_col0,#T_ae78b_row22_col0,#T_ae78b_row23_col0,#T_ae78b_row24_col0,#T_ae78b_row25_col0,#T_ae78b_row26_col0,#T_ae78b_row27_col0,#T_ae78b_row28_col0,#T_ae78b_row29_col0,#T_ae78b_row30_col0,#T_ae78b_row31_col0,#T_ae78b_row32_col0,#T_ae78b_row33_col0,#T_ae78b_row34_col0,#T_ae78b_row35_col0,#T_ae78b_row36_col0,#T_ae78b_row37_col0,#T_ae78b_row38_col0,#T_ae78b_row39_col0,#T_ae78b_row40_col0,#T_ae78b_row41_col0,#T_ae78b_row42_col0,#T_ae78b_row43_col0,#T_ae78b_row44_col0,#T_ae78b_row45_col0,#T_ae78b_row46_col0,#T_ae78b_row47_col0,#T_ae78b_row48_col0,#T_ae78b_row49_col0,#T_ae78b_row50_col0,#T_ae78b_row51_col0,#T_ae78b_row52_col0,#T_ae78b_row53_col0,#T_ae78b_row54_col0,#T_ae78b_row55_col0,#T_ae78b_row56_col0,#T_ae78b_row57_col0,#T_ae78b_row58_col0,#T_ae78b_row59_col0,#T_ae78b_row60_col0,#T_ae78b_row61_col0,#T_ae78b_row62_col0,#T_ae78b_row63_col0,#T_ae78b_row64_col0,#T_ae78b_row65_col0,#T_ae78b_row66_col0,#T_ae78b_row67_col0,#T_ae78b_row68_col0,#T_ae78b_row69_col0,#T_ae78b_row70_col0,#T_ae78b_row71_col0,#T_ae78b_row72_col0,#T_ae78b_row73_col0,#T_ae78b_row74_col0,#T_ae78b_row75_col0,#T_ae78b_row76_col0,#T_ae78b_row77_col0,#T_ae78b_row78_col0,#T_ae78b_row79_col0,#T_ae78b_row80_col0,#T_ae78b_row81_col0,#T_ae78b_row82_col0,#T_ae78b_row83_col0,#T_ae78b_row84_col0,#T_ae78b_row85_col0,#T_ae78b_row86_col0,#T_ae78b_row87_col0,#T_ae78b_row88_col0,#T_ae78b_row89_col0,#T_ae78b_row90_col0,#T_ae78b_row91_col0,#T_ae78b_row92_col0,#T_ae78b_row93_col0,#T_ae78b_row94_col0,#T_ae78b_row95_col0,#T_ae78b_row96_col0,#T_ae78b_row97_col0,#T_ae78b_row98_col0,#T_ae78b_row99_col0,#T_ae78b_row100_col0,#T_ae78b_row101_col0,#T_ae78b_row102_col0,#T_ae78b_row103_col0,#T_ae78b_row104_col0,#T_ae78b_row105_col0,#T_ae78b_row106_col0,#T_ae78b_row107_col0,#T_ae78b_row108_col0,#T_ae78b_row109_col0,#T_ae78b_row110_col0,#T_ae78b_row111_col0,#T_ae78b_row112_col0,#T_ae78b_row113_col0,#T_ae78b_row114_col0,#T_ae78b_row115_col0,#T_ae78b_row116_col0,#T_ae78b_row117_col0,#T_ae78b_row118_col0,#T_ae78b_row119_col0,#T_ae78b_row120_col0,#T_ae78b_row121_col0,#T_ae78b_row122_col0,#T_ae78b_row123_col0,#T_ae78b_row124_col0,#T_ae78b_row125_col0,#T_ae78b_row126_col0,#T_ae78b_row127_col0,#T_ae78b_row128_col0,#T_ae78b_row129_col0,#T_ae78b_row130_col0,#T_ae78b_row131_col0,#T_ae78b_row132_col0{
#             text-align:  left;
#         }</style><table id="T_ae78b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae78b_level0_row0" class="row_heading level0 row0" >TUCASEID</th>
#                         <td id="T_ae78b_row0_col0" class="data row0 col0" >ATUS Case ID (14-digit identifier)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row1" class="row_heading level0 row1" >TULINENO</th>
#                         <td id="T_ae78b_row1_col0" class="data row1 col0" >ATUS person line number</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row2" class="row_heading level0 row2" >TESPUHRS</th>
#                         <td id="T_ae78b_row2_col0" class="data row2 col0" >Edited: usual hours of work per week of spouse or unmarried partner</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row3" class="row_heading level0 row3" >TRDTIND1</th>
#                         <td id="T_ae78b_row3_col0" class="data row3 col0" >Detailed industry recode (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row4" class="row_heading level0 row4" >TRDTOCC1</th>
#                         <td id="T_ae78b_row4_col0" class="data row4 col0" >Detailed occupation recode (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row5" class="row_heading level0 row5" >TRERNHLY</th>
#                         <td id="T_ae78b_row5_col0" class="data row5 col0" >Hourly earnings at main job (2 implied decimals)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row6" class="row_heading level0 row6" >TRERNUPD</th>
#                         <td id="T_ae78b_row6_col0" class="data row6 col0" >Earnings update flag</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row7" class="row_heading level0 row7" >TRHERNAL</th>
#                         <td id="T_ae78b_row7_col0" class="data row7 col0" >TRERNHLY: allocation flag</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row8" class="row_heading level0 row8" >TRHHCHILD</th>
#                         <td id="T_ae78b_row8_col0" class="data row8 col0" >Presence of household children < 18</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row9" class="row_heading level0 row9" >TRIMIND1</th>
#                         <td id="T_ae78b_row9_col0" class="data row9 col0" >Intermediate industry recode (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row10" class="row_heading level0 row10" >TRMJIND1</th>
#                         <td id="T_ae78b_row10_col0" class="data row10 col0" >Major industry recode (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row11" class="row_heading level0 row11" >TRMJOCC1</th>
#                         <td id="T_ae78b_row11_col0" class="data row11 col0" >Major occupation recode (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row12" class="row_heading level0 row12" >TRMJOCGR</th>
#                         <td id="T_ae78b_row12_col0" class="data row12 col0" >Major occupation category (main job)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row13" class="row_heading level0 row13" >TRNHHCHILD</th>
#                         <td id="T_ae78b_row13_col0" class="data row13 col0" >Presence of own non-household child < 18</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row14" class="row_heading level0 row14" >TRNUMHOU</th>
#                         <td id="T_ae78b_row14_col0" class="data row14 col0" >Number of people living in respondent's household</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row15" class="row_heading level0 row15" >TROHHCHILD</th>
#                         <td id="T_ae78b_row15_col0" class="data row15 col0" >Presence of own household children < 18</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row16" class="row_heading level0 row16" >TRTALONE</th>
#                         <td id="T_ae78b_row16_col0" class="data row16 col0" >Total nonwork-related time respondent spent alone (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row17" class="row_heading level0 row17" >TRTCC</th>
#                         <td id="T_ae78b_row17_col0" class="data row17 col0" >Total time spent during diary day providing secondary childcare for  household and own nonhousehold children < 13 (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0_row18" class="row_heading level0 row18" >TRTHHFAMILY</th>
#                         <td id="T_ae78b_row18_col0" class="data row18 col0" >Total nonwork-related time respondent spent with household family  members (in minutes)</td>
#             </tr>
#             <tr>
#                         <th id="T_ae78b_level0

# %% [markdown]
# ## Roster File

# %%
columns = pd.read_csv('data/atusrost-0320/atusrost_0320.dat', nrows=1).columns

in_rostfile = parsed['file'].apply(lambda x: 'Roster File' in x or 'All Files' in x)

with pd.option_context("display.max_colwidth", 200):
    selected = parsed.loc[in_rostfile, ['name','description']]
    assert set(columns) == set(selected['name'].values)
    display.display(selected.set_index('name').loc[columns]
                    .style.set_properties(**{'text-align': 'left'}))
# Out:
# <style  type="text/css" >
# #T_61c64_row0_col0,#T_61c64_row1_col0,#T_61c64_row2_col0,#T_61c64_row3_col0,#T_61c64_row4_col0{
#             text-align:  left;
#         }</style><table id="T_61c64_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61c64_level0_row0" class="row_heading level0 row0" >TUCASEID</th>
#                         <td id="T_61c64_row0_col0" class="data row0 col0" >ATUS Case ID (14-digit identifier)</td>
#             </tr>
#             <tr>
#                         <th id="T_61c64_level0_row1" class="row_heading level0 row1" >TULINENO</th>
#                         <td id="T_61c64_row1_col0" class="data row1 col0" >ATUS person line number</td>
#             </tr>
#             <tr>
#                         <th id="T_61c64_level0_row2" class="row_heading level0 row2" >TERRP</th>
#                         <td id="T_61c64_row2_col0" class="data row2 col0" >Edited: how is this person related to you?</td>
#             </tr>
#             <tr>
#                         <th id="T_61c64_level0_row3" class="row_heading level0 row3" >TEAGE</th>
#                         <td id="T_61c64_row3_col0" class="data row3 col0" >Edited: age</td>
#             </tr>
#             <tr>
#                         <th id="T_61c64_level0_row4" class="row_heading level0 row4" >TESEX</th>
#                         <td id="T_61c64_row4_col0" class="data row4 col0" >Edited: sex</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Activity Lexicon

# %%
pdf = pdfplumber.open("data/Documentation/lexiconnoex0320.pdf")

# %%
page_tables = []
for page in pdf.pages[1:]:    # pp. 12-54
    tables = page.extract_tables()
    page_tables.append(tables)

# %%
# check first, second, and third level length
# corresponds to #tables, #rows, #columns
for t in page_tables:
    print(f"{len(t):3d} {len(t[0]):3d} {len(t[0][0]):3d}")
# Out:
#   1  62   5
#   1  64   5
#   1  63   5
#   1  62   5
#   1  62   5
#   1  64   5
#   1  64   5
#   1  54   5
#   1  58   5
#   1  23   5

# %%
# exclude first two rows on each page as they are repeated headers
dfs = [pd.DataFrame(t[0][2:]) for t in page_tables]
merged_df = pd.concat(dfs)

# %%
rows = []
current_major_category = None
first_second_tier_category = None
for t in page_tables:
    table = t[0][2:]
    for r in table:
        if r[0]:
            current_major_category = r[0]
#             rows.append([current_major_category,,,,])
        else:
            if r[1]:
                # HACK: to fix a couple of problematic rows
                r[1] = r[1].replace('0 808 S ecurity', '0808 Security')
                first_second_tier_category = r[1]
#                 rows.append([current_major_category, first_second_tier_category,,,])
            else:
                rows.append([current_major_category, first_second_tier_category] + r[2:])

# %%
lexicondf = pd.DataFrame(rows, columns=['Major','FirstSecondTier','6digit','Activity','Notes'])

# %%
lexicondf['MajorCode'] = lexicondf['Major'].str[:2]
lexicondf['FSTierCode'] = lexicondf['FirstSecondTier'].str[:4]
lexicondf['MajorDesc'] = lexicondf['Major'].str[3:].str.strip()

# %%
# sanity consistency check
assert (lexicondf['6digit'].str[:4] == lexicondf['FSTierCode']).all()

# %% [markdown]
# Number of subcategories for each major category:

# %%
lexicondf
# Out:
#                            Major           FirstSecondTier  6digit  \
# 0    01 Personal Care Activities            0101  Sleeping  010101
# 1    01 Personal Care Activities            0101  Sleeping  010102
# 2    01 Personal Care Activities            0101  Sleeping  010199
# 3    01 Personal Care Activities            0102  Grooming  010201
# 4    01 Personal Care Activities            0102  Grooming  010299
# ..                           ...                       ...     ...
# 426               50  Data Codes      5001  Unable to Code  500104
# 427               50  Data Codes      5001  Unable to Code  500105
# 428               50  Data Codes      5001  Unable to Code  500106
# 429               50  Data Codes      5001  Unable to Code  500107
# 430               50  Data Codes  5099 Data codes, n.e.c.*  509989
#
#                                               Activity  \
# 0                                             Sleeping
# 1                                        Sleeplessness
# 2                                    Sleeping, n.e.c.*
# 3               Washing, dressing and grooming oneself
# 4                                    Grooming, n.e.c.*
# ..                                                 ...
# 426       Recorded simultaneous activities incorrectly
# 427  Respondent refused to provide information/"non...
# 428                                 Gap/can't remember
# 429                Unable to code activity at 1st tier
# 430                                Data codes, n.e.c.*
#
#                                           Notes MajorCode FSTierCode  \
# 0                                                      01       0101
# 1                                                      01       0101
# 2                                                      01       0101
# 3                                                      01       0102
# 4                                                      01       0102
# ..                                          ...       ...        ...
# 426             code was used in 2003-2012 only        50       5001
# 427                                                    50       5001
# 428                                                    50       5001
# 429                                                    50       5001
# 430  includes 500102 (2003); 509999 (All years)        50       5099
#
#                     MajorDesc
# 0    Personal Care Activities
# 1    Personal Care Activities
# 2    Personal Care Activities
# 3    Personal Care Activities
# 4    Personal Care Activities
# ..                        ...
# 426                Data Codes
# 427                Data Codes
# 428                Data Codes
# 429                Data Codes
# 430                Data Codes
#
# [431 rows x 8 columns]

# %%
lexicondf["Major"].value_counts()
# Out:
# 13 Sports, Exercise, & Recreation                       77
# 18 Traveling                                            53
# 04 Caring For & Helping Nonhousehold (NonHH) Members    37
# 03 Caring For & Helping Household (HH) Members          33
# 02 Household Activities                                 32
# 12 Socializing, Relaxing, and Leisure                   31
# 08 Professional & Personal Care Services                26
# 15 Volunteer Activities                                 24
# 05 Work & Work-Related Activities                       20
# 09 Household Services                                   18
# 06 Education                                            18
# 01 Personal Care Activities                             12
# 10 Government Services & Civic Obligations              12
# 07 Consumer Purchases                                   11
# 16 Telephone Calls                                       9
# 50  Data Codes                                           7
# 14 Religious and Spiritual Activities                    6
# 11 Eating and Drinking                                   5
# Name: Major, dtype: int64

# %%
# %store lexicondf
# Out:
# Stored 'lexicondf' (DataFrame)
